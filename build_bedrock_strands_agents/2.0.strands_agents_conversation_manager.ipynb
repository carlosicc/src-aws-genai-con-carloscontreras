# %% [markdown]
# ## Gestor de Conversación
#
# > El SDK proporciona un sistema flexible para la gestión de contexto a través de la interfaz ConversationManager.

# %%
from strands import Agent
from strands.agent.conversation_manager import SlidingWindowConversationManager

# Create a conversation manager with custom window size
conversation_manager = SlidingWindowConversationManager(
    window_size=20,  # Maximum number of messages to keep
    should_truncate_results=True, # Enable truncating the tool result when a message is too large for the model's context window 
)

agent = Agent(
    conversation_manager=conversation_manager
)

# %% [markdown]
# ### Preguntemos a nuestro agente algo

# %%
agent("¿Cuál es el signficado de la vida?")

# %% [markdown]
# #### ¿Se acordará de la pregunta hecha? ¿Tendrá el contexto de lo que hablo?

# %%
agent("¿Y desde una perspectiva Aristotélica?")
